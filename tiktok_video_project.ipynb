# %%
import os
import sys
import pandas as pd
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

current_dir = os.getcwd()
src_path = os.path.join(current_dir, 'src')
if src_path not in sys.path:
    sys.path.append(src_path)

from tiktok_feature_extractor import TikTokFeatureExtractor
extractor = TikTokFeatureExtractor()

video_folder = "data/tiktok_videos"
output_folder = "data/tiktok_frames"
csv_output = "data/video_features_results.csv"

if not os.path.exists(video_folder):
    print(f"Video folder '{video_folder}' not found!")
    exit()
os.makedirs(output_folder, exist_ok=True)

video_files = [f for f in os.listdir(video_folder) if f.lower().endswith('.mp4')]
print(f"Found {len(video_files)} video files")

# %%
import sys, asyncio, nest_asyncio
sys.path.append('/app/src')
nest_asyncio.apply()

import src.main_batch as main_batch

sys.argv = [
    'main_batch',
    '--csv', '/app/data/creators.csv',
    '--batch-size', '3',
    '--concurrency', '3',
    '--limit-per-creator', '3',
    '-v'
]

await main_batch.main()
# Out:
# 2025-08-21 04:06:21,359 [INFO] main_batch: 🚀 Starting TikTok creator batch analysis
# 2025-08-21 04:06:21,439 [INFO] main_batch: ✅ Config loaded: config/config.yml
# 2025-08-21 04:06:21,441 [INFO] progress_manager: 🆕 Initialized new progress store
# 2025-08-21 04:06:21,442 [INFO] batch_processor: ✅ Batch processor ready: batch_size=5, concurrency=2
# 2025-08-21 04:06:21,443 [INFO] main_batch: 📊 Processing creators list: /app/data/creators.csv
# 2025-08-21 04:06:21,446 [INFO] main_batch:    File size: 3.7 KB
# 2025-08-21 04:06:21,447 [INFO] main_batch: ⚙️ Runtime config:
# 2025-08-21 04:06:21,448 [INFO] main_batch:    batch_size: 3
# 2025-08-21 04:06:21,449 [INFO] main_batch:    concurrency: 3
# 2025-08-21 04:06:21,451 [INFO] main_batch:    delay_between_batches: 10 sec
# 2025-08-21 04:06:21,452 [INFO] main_batch:    max_videos_per_creator: 3
# 2025-08-21 04:06:21,464 [INFO] batch_processor: 📊 Loaded 269 creators from CSV (encoding=utf-8)
# 2025-08-21 04:06:21,487 [INFO] progress_manager: 🆕 Created batch batch_20250821_040621 with 269 creators
# 2025-08-21 04:06:21,497 [INFO] batch_processor: 🚀 Starting batch processing for 269 creators, batch_size=3
# 2025-08-21 04:06:21,498 [INFO] batch_processor: 📦 Processing batch 1/90: 3 creators
# 2025-08-21 04:06:21,500 [INFO] batch_processor: 👤 Processing creator: boise_brooke
# 2025-08-21 04:06:21,507 [INFO] batch_processor: 👤 Processing creator: lalalakays
# 2025-08-21 04:06:21,515 [INFO] batch_processor: 👤 Processing creator: alexandrasfinds1
# 2025-08-21 04:06:28,096 [INFO] tiktok_crawler: TikTok sessions created using browser=chromium, headless=True
# 2025-08-21 04:06:32,473 [INFO] tiktok_crawler: Successfully fetched 3 videos for lalalakays via yt-dlp (preferred)
# 2025-08-21 04:06:33,378 [INFO] tiktok_crawler: Downloaded via yt-dlp to data/tiktok_videos/lalalakays_7540575930373246263.mp4
# 2025-08-21 04:06:34,400 [INFO] tiktok_crawler: Downloaded via yt-dlp to data/tiktok_videos/lalalakays_7540575509026065677.mp4
# 2025-08-21 04:06:35,394 [INFO] tiktok_crawler: Downloaded via yt-dlp to data/tiktok_videos/lalalakays_7540573285457644813.mp4
# 2025-08-21 04:06:35,526 [INFO] tiktok_crawler: TikTok sessions created using browser=chromium, headless=True
# 2025-08-21 04:06:38,277 [INFO] tiktok_crawler: Successfully fetched 3 videos for alexandrasfinds1 via yt-dlp (preferred)
# 2025-08-21 04:06:39,480 [INFO] tiktok_crawler: Downloaded via yt-dlp to data/tiktok_videos/alexandrasfinds1_7540866098422353166.mp4
# 2025-08-21 04:06:40,438 [INFO] tiktok_crawler: Downloaded via yt-dlp to data/tiktok_videos/alexandrasfinds1_7540784657613294862.mp4
# 2025-08-21 04:06:41,560 [INFO] tiktok_crawler: Downloaded via yt-dlp to data/tiktok_videos/alexandrasfinds1_7540744304839445815.mp4
# 2025-08-21 04:06:41,602 [INFO] tiktok_crawler: TikTok sessions created using browser=chromium, headless=True
# 2025-08-21 04:06:45,332 [INFO] tiktok_crawler: Successfully fetched 3 videos for boise_brooke via yt-dlp (preferred)
# 2025-08-21 04:06:46,747 [INFO] tiktok_crawler: Downloaded via yt-dlp to data/tiktok_videos/boise_brooke_7540861540593880334.mp4
# 2025-08-21 04:06:47,933 [INFO] tiktok_crawler: Downloaded via yt-dlp to data/tiktok_videos/boise_brooke_7540833756756725006.mp4
# 2025-08-21 04:06:50,201 [INFO] tiktok_crawler: Downloaded via yt-dlp to data/tiktok_videos/boise_brooke_7540799670956690702.mp4
# 2025-08-21 04:06:59,519 [INFO] shared_models: Transformers imported successfully
# 2025-08-21 04:06:59,758 [INFO] shared_models: CLIP imported successfully
# 2025-08-21 04:06:59,799 [INFO] shared_models: ModelScope imported successfully
# 2025-08-21 04:06:59,815 [INFO] shared_models: OpenAI client initialized successfully
# 2025-08-21 04:06:59,818 [INFO] shared_models: Loading YOLO-World model: models/yolov8s-world.pt
# 2025-08-21 04:07:00,070 [INFO] shared_models: Loading BLIP model...
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 2025-08-21 04:07:11,505 [INFO] shared_models: BLIP model loaded successfully
# 2025-08-21 04:07:11,507 [INFO] shared_models: Loading CLIP model...
# 2025-08-21 04:07:15,787 [INFO] shared_models: CLIP model loaded successfully
# 2025-08-21 04:07:15,805 [INFO] shared_models: GPT4O configuration loaded successfully
# 2025-08-21 04:07:15,822 [INFO] shared_models: Loading Whisper model (small)...
# 2025-08-21 04:07:20,044 [INFO] shared_models: Whisper small loaded on CUDA!
# Using cache found in /app/models/hub/snakers4_silero-vad_master
# 2025-08-21 04:07:20,585 [INFO] shared_models: Silero VAD model loaded successfully
# 2025-08-21 04:07:20,623 [INFO] shared_models: Loading Demucs model (pip version)...
# 2025-08-21 04:07:21,447 [INFO] shared_models: Demucs model loaded successfully
# 2025-08-21 04:07:21,580 [INFO] shazamio_core: Initializing shazamio_core module
# 2025-08-21 04:07:21,582 [INFO] shazamio_core: shazamio_core module initialized successfully
# 2025-08-21 04:07:21,603 [INFO] shared_models: Shazamio imported successfully
# 2025-08-21 04:07:21,604 [INFO] shazamio_core: Recognizer created with segment_duration_seconds = 10
# 2025-08-21 04:07:21,670 [INFO] AdvancedAudioProcessor: AdvancedAudioProcessor initialized on device: cuda
# 2025-08-21 04:07:21,672 [INFO] image_compressor: ImageCompressor initialized with max_dimension=512, quality=85, optimize=True
# 2025-08-21 04:07:21,672 [INFO] MultimodalExtractor: EmbeddingAnalyzer disabled by multimodal config (use_embedding_analyzer: false)
# 2025-08-21 04:07:21,673 [INFO] MultimodalExtractor: GPT4O config loaded: True
# 2025-08-21 04:07:21,674 [INFO] MultimodalExtractor: GPT4O prompt length: 7667 characters
# 2025-08-21 04:07:21,675 [INFO] MultimodalExtractor: Image compressor initialized: True
# 2025-08-21 04:07:21,677 [INFO] MultimodalExtractor: Image compression config: max_dimension=512, quality=85
# 2025-08-21 04:07:21,693 [INFO] tiktok: [extract_video_features] started
# 2025-08-21 04:07:21,701 [INFO] TikTokFeatureExtractor: Processing video: data/tiktok_videos/lalalakays_7540575930373246263.mp4
# 2025-08-21 04:07:21,708 [INFO] VideoProcessor: Extracting metadata for video: data/tiktok_videos/lalalakays_7540575930373246263.mp4
# /usr/local/lib/python3.11/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# 2025-08-21 04:07:22,000 [INFO] AdvancedAudioProcessor: AdvancedAudioProcessor initialized on device: cuda
# 2025-08-21 04:07:22,007 [INFO] image_compressor: ImageCompressor initialized with max_dimension=512, quality=85, optimize=True
# 2025-08-21 04:07:22,009 [INFO] MultimodalExtractor: EmbeddingAnalyzer disabled by multimodal config (use_embedding_analyzer: false)
# 2025-08-21 04:07:22,012 [INFO] MultimodalExtractor: GPT4O config loaded: True
# 2025-08-21 04:07:22,015 [INFO] MultimodalExtractor: GPT4O prompt length: 7667 characters
# 2025-08-21 04:07:22,017 [INFO] MultimodalExtractor: Image compressor initialized: True
# 2025-08-21 04:07:22,020 [INFO] MultimodalExtractor: Image compression config: max_dimension=512, quality=85
# 2025-08-21 04:07:22,037 [INFO] tiktok: [extract_video_features] started
# 2025-08-21 04:07:22,046 [INFO] TikTokFeatureExtractor: Processing video: data/tiktok_videos/alexandrasfinds1_7540866098422353166.mp4
# 2025-08-21 04:07:22,048 [INFO] VideoProcessor: Extracting metadata for video: data/tiktok_videos/alexandrasfinds1_7540866098422353166.mp4
# 2025-08-21 04:07:22,083 [INFO] AdvancedAudioProcessor: AdvancedAudioProcessor initialized on device: cuda
# 2025-08-21 04:07:22,085 [INFO] image_compressor: ImageCompressor initialized with max_dimension=512, quality=85, optimize=True
# 2025-08-21 04:07:22,086 [INFO] MultimodalExtractor: EmbeddingAnalyzer disabled by multimodal config (use_embedding_analyzer: false)
# 2025-08-21 04:07:22,087 [INFO] MultimodalExtractor: GPT4O config loaded: True
# 2025-08-21 04:07:22,089 [INFO] MultimodalExtractor: GPT4O prompt length: 7667 characters
# 2025-08-21 04:07:22,090 [INFO] MultimodalExtractor: Image compressor initialized: True
# 2025-08-21 04:07:22,091 [INFO] MultimodalExtractor: Image compression config: max_dimension=512, quality=85
# 2025-08-21 04:07:22,106 [INFO] tiktok: [extract_video_features] started
# 2025-08-21 04:07:22,115 [INFO] TikTokFeatureExtractor: Processing video: data/tiktok_videos/boise_brooke_7540861540593880334.mp4
# 2025-08-21 04:07:22,116 [INFO] VideoProcessor: Extracting metadata for video: data/tiktok_videos/boise_brooke_7540861540593880334.mp4
# /usr/local/lib/python3.11/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.11/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# 2025-08-21 04:07:23,821 [INFO] AudioSeparator: Two-stems separated and saved to: data/analysis/lalalakays/7540575930373246263/vocals.wav, data/analysis/lalalakays/7540575930373246263/non_vocals.wav
# 2025-08-21 04:07:23,825 [INFO] SpeechAnalyzer: Starting speech analysis for: data/analysis/lalalakays/7540575930373246263/vocals.wav
# 2025-08-21 04:07:23,827 [INFO] SpeechAnalyzer: Whisper model is loaded, proceeding with transcription...
# 2025-08-21 04:07:23,830 [INFO] SpeechAnalyzer: Starting transcription for: data/analysis/lalalakays/7540575930373246263/vocals.wav
# 2025-08-21 04:07:23,832 [INFO] SpeechAnalyzer: Starting Whisper transcription directly...
# 2025-08-21 04:07:23,834 [INFO] SpeechAnalyzer: Whisper options: {'task': 'transcribe', 'fp16': False, 'condition_on_previous_text': True, 'temperature': 0.0, 'compression_ratio_threshold': 2.4, 'logprob_threshold': -1.0, 'no_speech_threshold': 0.6}
# /usr/lib/python3.11/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# 2025-08-21 04:07:25,253 [INFO] AudioSeparator: Two-stems separated and saved to: data/analysis/boise_brooke/7540861540593880334/vocals.wav, data/analysis/boise_brooke/7540861540593880334/non_vocals.wav
# 2025-08-21 04:07:25,257 [INFO] AudioSeparator: Two-stems separated and saved to: data/analysis/alexandrasfinds1/7540866098422353166/vocals.wav, data/analysis/alexandrasfinds1/7540866098422353166/non_vocals.wav
# 2025-08-21 04:07:25,261 [INFO] SpeechAnalyzer: Starting speech analysis for: data/analysis/boise_brooke/7540861540593880334/vocals.wav
# 2025-08-21 04:07:25,262 [INFO] SpeechAnalyzer: Starting speech analysis for: data/analysis/alexandrasfinds1/7540866098422353166/vocals.wav
# 2025-08-21 04:07:25,262 [INFO] SpeechAnalyzer: Whisper model is loaded, proceeding with transcription...
# 2025-08-21 04:07:25,263 [INFO] SpeechAnalyzer: Whisper model is loaded, proceeding with transcription...
# 2025-08-21 04:07:25,264 [INFO] SpeechAnalyzer: Starting transcription for: data/analysis/boise_brooke/7540861540593880334/vocals.wav
# 2025-08-21 04:07:25,267 [INFO] SpeechAnalyzer: Starting transcription for: data/analysis/alexandrasfinds1/7540866098422353166/vocals.wav
# 2025-08-21 04:07:25,269 [INFO] SpeechAnalyzer: Starting Whisper transcription directly...
# 2025-08-21 04:07:25,272 [INFO] SpeechAnalyzer: Starting Whisper transcription directly...
# 2025-08-21 04:07:25,274 [INFO] SpeechAnalyzer: Whisper options: {'task': 'transcribe', 'fp16': False, 'condition_on_previous_text': True, 'temperature': 0.0, 'compression_ratio_threshold': 2.4, 'logprob_threshold': -1.0, 'no_speech_threshold': 0.6}
# 2025-08-21 04:07:25,276 [INFO] SpeechAnalyzer: Whisper options: {'task': 'transcribe', 'fp16': False, 'condition_on_previous_text': True, 'temperature': 0.0, 'compression_ratio_threshold': 2.4, 'logprob_threshold': -1.0, 'no_speech_threshold': 0.6}
# /usr/lib/python3.11/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# 2025-08-21 04:07:25,848 [INFO] SpeechAnalyzer: Whisper transcription completed - language: nn
# 2025-08-21 04:07:25,849 [INFO] SpeechAnalyzer: Raw transcription:  �...
# 2025-08-21 04:07:25,852 [INFO] SpeechAnalyzer: Transcription result - confidence: 0.361
# 2025-08-21 04:07:25,853 [INFO] SpeechAnalyzer: Raw text:  �...
# 2025-08-21 04:07:25,857 [INFO] SpeechAnalyzer: Speech analysis completed (confidence: 0.36, length: 0)
# 2025-08-21 04:07:25,859 [INFO] SpeechAnalyzer: Processed text: ...
# 2025-08-21 04:07:25,861 [INFO] SpeechRateAnalyzer: Starting speech rate analysis for: data/analysis/lalalakays/7540575930373246263/vocals.wav
# 2025-08-21 04:07:25,863 [INFO] SpeechRateAnalyzer: Speech rate analysis completed - Overall score: 0.0/10
# 2025-08-21 04:07:25,865 [INFO] AdvancedAudioProcessor: Speech analysis completed - confidence: 0.36, text length: 0)
# 2025-08-21 04:07:25,867 [INFO] AdvancedAudioProcessor: No speech text extracted
# 2025-08-21 04:07:25,870 [INFO] AdvancedAudioProcessor: Speech rate analysis completed - Overall score: 0.0/10, WPM: 0.0
# 2025-08-21 04:07:25,872 [INFO] AdvancedAudioProcessor: Speech rate category: no_speech
# 2025-08-21 04:07:25,875 [INFO] AdvancedAudioProcessor: Speech rate recommendation: No speech detected (0.0 WPM). This video appears to have no spoken content.
# 2025-08-21 04:07:26,123 [INFO] SpeechAnalyzer: Whisper transcription completed - language: en
# 2025-08-21 04:07:26,125 [INFO] SpeechAnalyzer: Raw transcription: ...
# 2025-08-21 04:07:26,126 [INFO] SpeechAnalyzer: Transcription result - confidence: 0.173
# 2025-08-21 04:07:26,127 [INFO] SpeechAnalyzer: Raw text: ...
# 2025-08-21 04:07:26,129 [INFO] SpeechAnalyzer: Speech analysis completed (confidence: 0.17, length: 0)
# 2025-08-21 04:07:26,131 [INFO] SpeechAnalyzer: Processed text: ...
# 2025-08-21 04:07:26,133 [INFO] SpeechRateAnalyzer: Starting speech rate analysis for: data/analysis/boise_brooke/7540861540593880334/vocals.wav
# 2025-08-21 04:07:26,135 [INFO] SpeechRateAnalyzer: Speech rate analysis completed - Overall score: 0.0/10
# 2025-08-21 04:07:26,138 [INFO] AdvancedAudioProcessor: Speech analysis completed - confidence: 0.17, text length: 0)
# 2025-08-21 04:07:26,141 [INFO] AdvancedAudioProcessor: No speech text extracted
# 2025-08-21 04:07:26,144 [INFO] AdvancedAudioProcessor: Speech rate analysis completed - Overall score: 0.0/10, WPM: 0.0
# 2025-08-21 04:07:26,147 [INFO] MusicAnalyzer: Music analysis finished for data/analysis/lalalakays/7540575930373246263/non_vocals.wav
# 2025-08-21 04:07:26,147 [INFO] AdvancedAudioProcessor: Speech rate category: no_speech
# 2025-08-21 04:07:26,151 [INFO] AdvancedAudioProcessor: Speech rate recommendation: No speech detected (0.0 WPM). This video appears to have no spoken content.
# 2025-08-21 04:07:26,160 [INFO] AdvancedAudioProcessor: Results saved to: data/analysis/lalalakays/7540575930373246263
# 2025-08-21 04:07:26,163 [INFO] TikTokFeatureExtractor: Keyframe extraction started
# 2025-08-21 04:07:26,470 [INFO] MusicAnalyzer: Music analysis finished for data/analysis/boise_brooke/7540861540593880334/non_vocals.wav
# 2025-08-21 04:07:26,483 [INFO] AdvancedAudioProcessor: Results saved to: data/analysis/boise_brooke/7540861540593880334
# 2025-08-21 04:07:26,485 [INFO] TikTokFeatureExtractor: Keyframe extraction started
# 2025-08-21 04:07:28,876 [INFO] TikTokFeatureExtractor: Frame analysis started
# 2025-08-21 04:07:32,387 [INFO] SpeechAnalyzer: Whisper transcription completed - language: en
# 2025-08-21 04:07:32,388 [INFO] SpeechAnalyzer: Raw transcription:  Just look at that length and volume it gave my lashes and something like crazy for a reason if you ...
# 2025-08-21 04:07:32,389 [INFO] SpeechAnalyzer: Transcription result - confidence: 0.263
# 2025-08-21 04:07:32,390 [INFO] SpeechAnalyzer: Raw text:  Just look at that length and volume it gave my lashes and something like crazy for a reason if you ...
# 2025-08-21 04:07:32,392 [INFO] SpeechAnalyzer: Speech analysis completed (confidence: 0.26, length: 165)
# 2025-08-21 04:07:32,393 [INFO] SpeechAnalyzer: Processed text: Just look at that length and volume it gave my lashes and something crazy for a reason if you guys w...
# 2025-08-21 04:07:32,395 [INFO] SpeechRateAnalyzer: Starting speech rate analysis for: data/analysis/alexandrasfinds1/7540866098422353166/vocals.wav
# 2025-08-21 04:07:32,396 [INFO] SpeechRateAnalyzer: Speech rate analysis completed - Overall score: 0.0/10
# 2025-08-21 04:07:32,398 [INFO] AdvancedAudioProcessor: Speech analysis completed - confidence: 0.26, text length: 165)
# 2025-08-21 04:07:32,399 [INFO] AdvancedAudioProcessor: Speech text: Just look at that length and volume it gave my lashes and something crazy for a reason if you guys w...
# 2025-08-21 04:07:32,401 [INFO] AdvancedAudioProcessor: Speech rate analysis completed - Overall score: 0.0/10, WPM: 0.0
# 2025-08-21 04:07:32,402 [INFO] AdvancedAudioProcessor: Speech rate category: no_speech
# 2025-08-21 04:07:32,404 [INFO] AdvancedAudioProcessor: Speech rate recommendation: No speech detected (0.0 WPM). This video appears to have no spoken content.
# 2025-08-21 04:07:32,436 [INFO] TikTokFeatureExtractor: Frame analysis started
# 2025-08-21 04:07:32,725 [INFO] MusicAnalyzer: Music analysis finished for data/analysis/alexandrasfinds1/7540866098422353166/non_vocals.wav
# 2025-08-21 04:07:32,747 [INFO] AdvancedAudioProcessor: Results saved to: data/analysis/alexandrasfinds1/7540866098422353166
# 2025-08-21 04:07:32,750 [INFO] TikTokFeatureExtractor: Keyframe extraction started
# 2025-08-21 04:07:33,593 [INFO] TikTokFeatureExtractor: Frame analysis started
# 2025-08-21 04:07:41,342 [INFO] frame_analyzer: Selecting representative frames for video: lalalakays_7540575930373246263
# 0: 640x384 1 person, 1 bottle, 1 apple, 18.1ms
# 1: 640x384 1 person, 2 bottles, 1 apple, 18.1ms
# 2: 640x384 1 person, 2 bottles, 1 apple, 18.1ms
# 3: 640x384 1 person, 2 bottles, 1 apple, 18.1ms
# 4: 640x384 2 persons, 2 bottles, 1 cup, 1 apple, 18.1ms
# 5: 640x384 1 person, 2 bottles, 1 apple, 18.1ms
# 6: 640x384 1 person, 3 bottles, 1 apple, 18.1ms
# 7: 640x384 3 bottles, 1 apple, 18.1ms
# 8: 640x384 1 person, 2 bottles, 1 apple, 18.1ms
# 9: 640x384 3 bottles, 18.1ms
# 10: 640x384 3 bottles, 18.1ms
# 11: 640x384 2 bottles, 18.1ms
# 12: 640x384 2 bottles, 18.1ms
# 13: 640x384 2 bottles, 18.1ms
# 14: 640x384 2 bottles, 18.1ms
# 15: 640x384 2 bottles, 18.1ms
# Speed: 6.0ms preprocess, 18.1ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 384)
# 2025-08-21 04:07:44,456 [INFO] frame_analyzer: Found 0 product frames, 16 non-product frames
# 2025-08-21 04:07:44,578 [INFO] frame_analyzer: Selecting representative frames for video: alexandrasfinds1_7540866098422353166
# 2025-08-21 04:07:45,579 [INFO] frame_analyzer: Selected 3 frames with CLIP.
# 2025-08-21 04:07:45,583 [INFO] frame_analyzer: Selected 3 representative frames for video: lalalakays_7540575930373246263
# 2025-08-21 04:07:45,653 [INFO] frame_analyzer: After cleanup, video_dir files: ['audio_analysis_results.json', 'lalalakays_7540575930373246263.wav', 'non_vocals.wav', 'representative_lalalakays_7540575930373246263_frame_0000.jpg', 'representative_lalalakays_7540575930373246263_frame_0001.jpg', 'representative_lalalakays_7540575930373246263_frame_0002.jpg', 'speech_transcription.txt', 'vocals.wav']
# 2025-08-21 04:07:45,662 [INFO] TikTokFeatureExtractor: Multimodal feature extraction started (GPT4O enabled)
# 2025-08-21 04:07:45,665 [INFO] MultimodalExtractor: Configuration: batch_image_upload=True, embedding_analysis=False
# 2025-08-21 04:07:45,669 [INFO] MultimodalExtractor: Using batch image upload mode for GPT4O analysis
# 2025-08-21 04:07:45,671 [INFO] MultimodalExtractor: Compressing images to optimize token usage...
# 2025-08-21 04:07:45,676 [INFO] image_compressor: Original image: 1080x1920
# 2025-08-21 04:07:45,721 [INFO] image_compressor: Compressed image: 288x512
# 2025-08-21 04:07:45,723 [INFO] image_compressor: Image compressed and replaced original: data/analysis/lalalakays/7540575930373246263/representative_lalalakays_7540575930373246263_frame_0000.jpg
# 2025-08-21 04:07:45,729 [INFO] image_compressor: Original image: 1080x1920
# 2025-08-21 04:07:45,778 [INFO] image_compressor: Compressed image: 288x512
# 2025-08-21 04:07:45,780 [INFO] image_compressor: Image compressed and replaced original: data/analysis/lalalakays/7540575930373246263/representative_lalalakays_7540575930373246263_frame_0001.jpg
# 2025-08-21 04:07:45,783 [INFO] image_compressor: Original image: 1080x1920
# 2025-08-21 04:07:45,825 [INFO] image_compressor: Compressed image: 288x512
# 2025-08-21 04:07:45,826 [INFO] image_compressor: Image compressed and replaced original: data/analysis/lalalakays/7540575930373246263/representative_lalalakays_7540575930373246263_frame_0002.jpg
# 2025-08-21 04:07:45,828 [INFO] MultimodalExtractor: Running YOLO batch inference on 3 images.
# 0: 640x384 1 person, 2 bottles, 49.4ms
# 1: 640x384 1 person, 2 bottles, 49.4ms
# 2: 640x384 1 person, 2 bottles, 49.4ms
# Speed: 1.8ms preprocess, 49.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 2025-08-21 04:07:46,038 [INFO] MultimodalExtractor: YOLO batch inference finished. Total objects: 9
# 2025-08-21 04:07:46,041 [INFO] MultimodalExtractor: Running BLIP batch captioning on 3 images.
# 0: 640x384 1 person, 32.0ms
# 1: 640x384 1 person, 1 couch, 32.0ms
# 2: 640x384 1 person, 32.0ms
# 3: 640x384 1 person, 1 toothbrush, 32.0ms
# 4: 640x384 1 person, 32.0ms
# Speed: 1.5ms preprocess, 32.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
# 2025-08-21 04:07:46,791 [INFO] frame_analyzer: Found 1 product frames, 4 non-product frames
# 2025-08-21 04:07:46,975 [INFO] MultimodalExtractor: BLIP batch captioning finished. Total captions: 3
# 2025-08-21 04:07:46,977 [INFO] MultimodalExtractor: ================================================================================
# 2025-08-21 04:07:46,978 [INFO] MultimodalExtractor: GPT4O BATCH PROMPT MONITORING
# 2025-08-21 04:07:46,980 [INFO] MultimodalExtractor: ================================================================================
# 2025-08-21 04:07:46,982 [INFO] MultimodalExtractor: Number of frames: 3
# 2025-08-21 04:07:46,983 [INFO] MultimodalExtractor: Prompt length: 8694 characters
# 2025-08-21 04:07:46,985 [INFO] MultimodalExtractor: Prompt content:
# 2025-08-21 04:07:46,987 [INFO] MultimodalExtractor: ----------------------------------------
# 2025-08-21 04:07:46,989 [INFO] MultimodalExtractor: You are a professional TikTok video content analysis expert with comprehensive knowledge of TikTok's content creator tag system.
# Analyze the provided video content (including frames, audio transcript, and metadata) and return ONLY a valid JSON response with the following unified structure:
#
# {
#   "video_description": "comprehensive description of the entire video content",
#   "primary_category": "beauty & personal care|fashion & accessories|home & lifestyle|sports & fitness|health & wellness|parenting & family|food & beverage|technology & gadgets|entertainment & gaming|travel & adventure|education & learning|pets & animals|automotive & transportation|business & finance|art & creativity|diy & crafts|comedy|dance|music|news & politics|science & nature|other",
#   "secondary_category": "skincare|makeup|haircare|fragrance|clothing|shoes|accessories|jewelry|home decor|kitchenware|gardening|fitness equipment|supplements|diet|mental health|recipes|restaurants|baking|adventure|hotels|budget travel|gadgets|apps|software|consoles|mobile games|team sports|yoga|running|early education|language learning|toddler care|teen issues|dog care|cat care|car reviews|motorcycles|investing|entrepreneurship|movies|tv shows|painting|knitting|woodworking|standup|skits|choreography|cover songs|current events|environment|other",
#   "tertiary_category": "specific product type or niche within secondary category",
#
#   "creator_analysis": {
#     "gender": "male|female|multiple-people|non-human|unknown",
#     "age": "child|teen|20s|30s|40s|50+|unknown",
#     "physical_appearance": "very appealing|appealing|average|distinctive|unknown",
#     "body_type": "slim|average|athletic|curvy|plus-size|unknown",
#     "hair_color": "black|brunette|blonde|red|mixed-colored|unknown|not-visible",
#     "hair_type": "straight|wavy|curly|coily|updo|tied|braids|unknown|not-visible",
#     "persona": ["fashionista|beauty guru|fitness enthusiast|foodie|traveler|tech geek|gamer|mommy blogger|pet lover|financial advisor|comedian|dancer|musician|educator|activist|artist|craftsman|lifestyle coach|health expert|reviewer|unboxer|vlogger|storyteller|influencer|model|expert"],
#     "charisma_authenticity": "enthusiastic & energetic|professional & authoritative|authentic & relatable|engaging & expressive|calm & soothing|unknown",
#     "economic_status": "luxury-focused|middle-class|budget-conscious|minimalist|unknown"
#   },
#
#   "content_analysis": {
#     "niche_specialty": ["skincare routines|makeup tutorials|hair styling|outfit ideas|home organization|workout plans|healthy recipes|travel hacks|tech reviews|gaming walkthroughs|parenting advice|pet training|car maintenance|investment tips|comedy skits|dance tutorials|song covers|educational content|art tutorials|diy projects|fashion hauls|beauty hauls|food reviews|budget travel tips|luxury unboxing|fitness challenges|mental health awareness|sustainable living"],
#     "content_format": ["tutorial|review|vlog|Q&A|challenge|prank|haul|day-in-the-life|how-to|tips & tricks|storytime|pov|comedy sketch|dance video|music video|educational|inspirational|motivational|interview|behind-the-scenes|unboxing|comparison|transformation|live stream"],
#     "overall_tone": ["informative|humorous|inspirational|relaxing|dramatic|romantic|sarcastic|upbeat|serious|mysterious|suspenseful|heartwarming|emotional|empowering|casual|formal"],
#     "energy_levels": "vibrant & passionate|composed & professional|calm & soothing|energetic & dynamic|relaxed & peaceful|unknown",
#     "visual_presentation": ["minimalist|bright & colorful|dark & moody|warm & cozy|professional lighting|natural lighting|dynamic editing|cinematic|aesthetic|raw & unfiltered|retro|futuristic|vintage"],
#     "product_presentation": ["product showcase|unboxing & reviews|voiceover content|live demonstrations|before & after comparisons|product comparisons|tutorial|haul|gift guide|collection|restock|routine|get ready with me|what's in my bag|try on haul"],
#     "video_quality": "very-high|high|moderate|low|unknown",
#     "video_scene": "daily life|family life|at work|professional settings|outdoor activities|social activities|travel scenes|special occasions|studio|bedroom|bathroom|kitchen|living room|garden|gym|cafe|restaurant|store|beach|mountains|city|countryside|other",
#     "video_background": "indoor|outdoor|kitchen|bedroom|living room|bathroom|office|studio|gym|cafe|restaurant|store|beach|mountains|city street|park|other",
#     "pacing": "very-fast|fast|moderate|slow|very-slow|unknown",
#     "speech_rate": "very-fast|fast|moderate|slow|very-slow|no-speech|unknown",
#     "face_visibility": "always-visible|frequently-visible|occasionally-visible|rarely-visible|never-visible|unknown",
#     "tiktok_effects": ["filters|ar-effects|text-overlay|green-screen|split-screens|stitches|duets|slow-motion|time-lapse|zoom-effects|transition-effects|voice-effects|stickers|emoji|none"]
#   },
#
#   "business_analysis": {
#     "commercial_intent": "commercial|non-commercial|educational|promotional|informational|entertainment|mixed",
#     "product_placement": "explicit|subtle|none|prominent|background|integrated",
#     "target_audience": "Detailed description of intended viewer demographics and interests",
#     "target_audience_fit": "low|moderate|high|very-high|unknown",
#     "engagement_drivers": ["promotional-sales|controversial-topics|clickbait|exaggerated-expression|relatable-struggle|satisfying-process|motivational-message|humor|emotional-story|shocking-facts|interactive-polls|user-participation|trending-music|celebration-events|exclusive-content"],
#     "trend_adoption": ["dance-challenges|audio-trends|meme-adaptations|pov-storytelling|seasonal-themes|hashtag-challenges|transition-challenges|outfit-challenges|recipe-trends|fitness-challenges|beauty-trends|comedy-trends|duet-chains|stitch-reactions"],
#     "branding_integration": "subtle|moderate|overt|not-present|seamless|forced|other",
#     "call_to_actions": ["like|share|comment|follow|link-in-bio|swipe-up|buy-now|join-live-stream|save|tag-friends|visit-website|download-app|sign-up|enter-giveaway|use-code"],
#     "has_discount": true,
#     "has_limited_time_discount": true,
#     "has_exclusive_discount": true
#   },
#
#   "product_analysis": {
#     "key_products": ["Product Name 1", "Product Name 2"],
#     "brands_mentioned": ["Brand 1", "Brand 2"],
#     "selling_points": ["Key benefit 1", "Key benefit 2"],
#     "content_creative_ideas": "Description of innovative presentation approaches",
#     "emotional_value": "Description of emotional resonance created",
#   },
#
#   "user_analysis": {
#     "user_demographics": "Target user group description",
#     "user_preferences": "Typical preferences of target audience",
#     "user_pain_points": "Key frustrations addressed",
#     "user_goals": "Aspirations and objectives of users"
#   },
#
#   "performance_analysis": {
#     "content_style": "Description of stylistic approach",
#     "engagement_potential": "high|medium|low|very-high|unknown",
#     "trend_alignment": ["Current trend 1", "Current trend 2"],
#     "compliance_issues": ["auctions|exaggerated promises|false or misleading info|gambling & gamification|illegal or criminal activity|other"]
#   },
#
#   "optimization_suggestions": {
#     "content": ["Suggestion 1", "Suggestion 2"],
#     "product_placement": ["Suggestion 1", "Suggestion 2"],
#     "content_creative_ideas": ["Suggestion 1", "Suggestion 2"],
#     "emotional_value": ["Suggestion 1", "Suggestion 2"],
#     "compliance_issues": ["Suggestion 1", "Suggestion 2"]
#   }
# }
#
# IMPORTANT: Return ONLY the JSON object, no additional text or explanations. Use the exact field names and structure provided above. Choose values ONLY from the enumerated options provided for each field.
#
# API METADATA (from TikTok API):
# - Creator: lalalakays
# - Video ID: 7540575930373246263
# - Description: Newest Scent 💚 #PHLUR Mrs. Smith Body Mist #bodymist #phlurmrssmith #TiktokShopCreatorPicks #CreatorIcons
# - Hashtags: PHLUR, bodymist, phlurmrssmith, TiktokShopCreatorPicks, CreatorIcons
# - Is Ad: False, Is Commerce: False, Ad Authorization: False
# - Stats: likes=9, comments=1, shares=0, views=562
# - Duration: 10s, Created: 2025-08-20T08:06:11
#
#
# Audio transcription content:
#
# Frame 1 (representative_lalalakays_7540575930373246263_frame_0000.jpg):
# - BLIP description: a person holding a bottle of liquid in their hand
# - Detected objects: person, bottle, bottle
#
# Frame 2 (representative_lalalakays_7540575930373246263_frame_0001.jpg):
# - BLIP description: a person holding a bottle of liquid in their hand
# - Detected objects: person, bottle, bottle
#
# Frame 3 (representative_lalalakays_7540575930373246263_frame_0002.jpg):
# - BLIP description: a person holding a bottle of green liquid
# - Detected objects: person, bottle, bottle
# 2025-08-21 04:07:46,992 [INFO] MultimodalExtractor: ----------------------------------------
# 2025-08-21 04:07:47,091 [INFO] frame_analyzer: Selected 2 frames with CLIP.
# 2025-08-21 04:07:47,096 [INFO] frame_analyzer: Selected 3 representative frames for video: alexandrasfinds1_7540866098422353166
# 2025-08-21 04:07:47,581 [INFO] frame_analyzer: After cleanup, video_dir files: ['alexandrasfinds1_7540866098422353166.wav', 'audio_analysis_results.json', 'non_vocals.wav', 'representative_alexandrasfinds1_7540866098422353166_frame_0000.jpg', 'representative_alexandrasfinds1_7540866098422353166_frame_0001.jpg', 'representative_alexandrasfinds1_7540866098422353166_frame_0002.jpg', 'speech_transcription.txt', 'vocals.wav']
# 2025-08-21 04:07:47,589 [INFO] TikTokFeatureExtractor: Multimodal feature extraction started (GPT4O enabled)
# 2025-08-21 04:07:47,591 [INFO] MultimodalExtractor: Configuration: batch_image_upload=True, embedding_analysis=False
# 2025-08-21 04:07:47,592 [INFO] MultimodalExtractor: Using batch image upload mode for GPT4O analysis
# 2025-08-21 04:07:47,594 [INFO] MultimodalExtractor: Compressing images to optimize token usage...
# 2025-08-21 04:07:47,603 [INFO] image_compressor: Original image: 720x1280
# 2025-08-21 04:07:47,645 [INFO] image_compressor: Compressed image: 288x512
# 2025-08-21 04:07:47,647 [INFO] image_compressor: Image compressed and replaced original: data/analysis/alexandrasfinds1/7540866098422353166/representative_alexandrasfinds1_7540866098422353166_frame_0000.jpg
# 2025-08-21 04:07:47,653 [INFO] image_compressor: Original image: 720x1280
# 2025-08-21 04:07:47,683 [INFO] image_compressor: Compressed image: 288x512
# 2025-08-21 04:07:47,686 [INFO] image_compressor: Image compressed and replaced original: data/analysis/alexandrasfinds1/7540866098422353166/representative_alexandrasfinds1_7540866098422353166_frame_0001.jpg
# 2025-08-21 04:07:47,692 [INFO] image_compressor: Original image: 720x1280
# 2025-08-21 04:07:47,725 [INFO] image_compressor: Compressed image: 288x512
# 2025-08-21 04:07:47,727 [INFO] image_compressor: Image compressed and replaced original: data/analysis/alexandrasfinds1/7540866098422353166/representative_alexandrasfinds1_7540866098422353166_frame_0002.jpg
# 2025-08-21 04:07:47,730 [INFO] MultimodalExtractor: Running YOLO batch inference on 3 images.
# 0: 640x384 1 person, 1 toothbrush, 44.5ms
# 1: 640x384 1 person, 44.5ms
# 2: 640x384 1 person, 44.5ms
# Speed: 4.9ms preprocess, 44.5ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 384)
# 2025-08-21 04:07:47,972 [INFO] MultimodalExtractor: YOLO batch inference finished. Total objects: 4
# 2025-08-21 04:07:47,974 [INFO] MultimodalExtractor: Running BLIP batch captioning on 3 images.
# 2025-08-21 04:07:48,759 [INFO] MultimodalExtractor: BLIP batch captioning finished. Total captions: 3
# 2025-08-21 04:07:48,761 [INFO] MultimodalExtractor: ================================================================================
# 2025-08-21 04:07:48,762 [INFO] MultimodalExtractor: GPT4O BATCH PROMPT MONITORING
# 2025-08-21 04:07:48,762 [INFO] MultimodalExtractor: ================================================================================
# 2025-08-21 04:07:48,764 [INFO] MultimodalExtractor: Number of frames: 3
# 2025-08-21 04:07:48,764 [INFO] MultimodalExtractor: Prompt length: 9038 characters
# 2025-08-21 04:07:48,765 [INFO] MultimodalExtractor: Prompt content:
# 2025-08-21 04:07:48,766 [INFO] MultimodalExtractor: ----------------------------------------
# 2025-08-21 04:07:48,768 [INFO] MultimodalExtractor: You are a professional TikTok video content analysis expert with comprehensive knowledge of TikTok's content creator tag system.
# Analyze the provided video content (including frames, audio transcript, and metadata) and return ONLY a valid JSON response with the following unified structure:
#
# {
#   "video_description": "comprehensive description of the entire video content",
#   "primary_category": "beauty & personal care|fashion & accessories|home & lifestyle|sports & fitness|health & wellness|parenting & family|food & beverage|technology & gadgets|entertainment & gaming|travel & adventure|education & learning|pets & animals|automotive & transportation|business & finance|art & creativity|diy & crafts|comedy|dance|music|news & politics|science & nature|other",
#   "secondary_category": "skincare|makeup|haircare|fragrance|clothing|shoes|accessories|jewelry|home decor|kitchenware|gardening|fitness equipment|supplements|diet|mental health|recipes|restaurants|baking|adventure|hotels|budget travel|gadgets|apps|software|consoles|mobile games|team sports|yoga|running|early education|language learning|toddler care|teen issues|dog care|cat care|car reviews|motorcycles|investing|entrepreneurship|movies|tv shows|painting|knitting|woodworking|standup|skits|choreography|cover songs|current events|environment|other",
#   "tertiary_category": "specific product type or niche within secondary category",
#
#   "creator_analysis": {
#     "gender": "male|female|multiple-people|non-human|unknown",
#     "age": "child|teen|20s|30s|40s|50+|unknown",
#     "physical_appearance": "very appealing|appealing|average|distinctive|unknown",
#     "body_type": "slim|average|athletic|curvy|plus-size|unknown",
#     "hair_color": "black|brunette|blonde|red|mixed-colored|unknown|not-visible",
#     "hair_type": "straight|wavy|curly|coily|updo|tied|braids|unknown|not-visible",
#     "persona": ["fashionista|beauty guru|fitness enthusiast|foodie|traveler|tech geek|gamer|mommy blogger|pet lover|financial advisor|comedian|dancer|musician|educator|activist|artist|craftsman|lifestyle coach|health expert|reviewer|unboxer|vlogger|storyteller|influencer|model|expert"],
#     "charisma_authenticity": "enthusiastic & energetic|professional & authoritative|authentic & relatable|engaging & expressive|calm & soothing|unknown",
#     "economic_status": "luxury-focused|middle-class|budget-conscious|minimalist|unknown"
#   },
#
#   "content_analysis": {
#     "niche_specialty": ["skincare routines|makeup tutorials|hair styling|outfit ideas|home organization|workout plans|healthy recipes|travel hacks|tech reviews|gaming walkthroughs|parenting advice|pet training|car maintenance|investment tips|comedy skits|dance tutorials|song covers|educational content|art tutorials|diy projects|fashion hauls|beauty hauls|food reviews|budget travel tips|luxury unboxing|fitness challenges|mental health awareness|sustainable living"],
#     "content_format": ["tutorial|review|vlog|Q&A|challenge|prank|haul|day-in-the-life|how-to|tips & tricks|storytime|pov|comedy sketch|dance video|music video|educational|inspirational|motivational|interview|behind-the-scenes|unboxing|comparison|transformation|live stream"],
#     "overall_tone": ["informative|humorous|inspirational|relaxing|dramatic|romantic|sarcastic|upbeat|serious|mysterious|suspenseful|heartwarming|emotional|empowering|casual|formal"],
#     "energy_levels": "vibrant & passionate|composed & professional|calm & soothing|energetic & dynamic|relaxed & peaceful|unknown",
#     "visual_presentation": ["minimalist|bright & colorful|dark & moody|warm & cozy|professional lighting|natural lighting|dynamic editing|cinematic|aesthetic|raw & unfiltered|retro|futuristic|vintage"],
#     "product_presentation": ["product showcase|unboxing & reviews|voiceover content|live demonstrations|before & after comparisons|product comparisons|tutorial|haul|gift guide|collection|restock|routine|get ready with me|what's in my bag|try on haul"],
#     "video_quality": "very-high|high|moderate|low|unknown",
#     "video_scene": "daily life|family life|at work|professional settings|outdoor activities|social activities|travel scenes|special occasions|studio|bedroom|bathroom|kitchen|living room|garden|gym|cafe|restaurant|store|beach|mountains|city|countryside|other",
#     "video_background": "indoor|outdoor|kitchen|bedroom|living room|bathroom|office|studio|gym|cafe|restaurant|store|beach|mountains|city street|park|other",
#     "pacing": "very-fast|fast|moderate|slow|very-slow|unknown",
#     "speech_rate": "very-fast|fast|moderate|slow|very-slow|no-speech|unknown",
#     "face_visibility": "always-visible|frequently-visible|occasionally-visible|rarely-visible|never-visible|unknown",
#     "tiktok_effects": ["filters|ar-effects|text-overlay|green-screen|split-screens|stitches|duets|slow-motion|time-lapse|zoom-effects|transition-effects|voice-effects|stickers|emoji|none"]
#   },
#
#   "business_analysis": {
#     "commercial_intent": "commercial|non-commercial|educational|promotional|informational|entertainment|mixed",
#     "product_placement": "explicit|subtle|none|prominent|background|integrated",
#     "target_audience": "Detailed description of intended viewer demographics and interests",
#     "target_audience_fit": "low|moderate|high|very-high|unknown",
#     "engagement_drivers": ["promotional-sales|controversial-topics|clickbait|exaggerated-expression|relatable-struggle|satisfying-process|motivational-message|humor|emotional-story|shocking-facts|interactive-polls|user-participation|trending-music|celebration-events|exclusive-content"],
#     "trend_adoption": ["dance-challenges|audio-trends|meme-adaptations|pov-storytelling|seasonal-themes|hashtag-challenges|transition-challenges|outfit-challenges|recipe-trends|fitness-challenges|beauty-trends|comedy-trends|duet-chains|stitch-reactions"],
#     "branding_integration": "subtle|moderate|overt|not-present|seamless|forced|other",
#     "call_to_actions": ["like|share|comment|follow|link-in-bio|swipe-up|buy-now|join-live-stream|save|tag-friends|visit-website|download-app|sign-up|enter-giveaway|use-code"],
#     "has_discount": true,
#     "has_limited_time_discount": true,
#     "has_exclusive_discount": true
#   },
#
#   "product_analysis": {
#     "key_products": ["Product Name 1", "Product Name 2"],
#     "brands_mentioned": ["Brand 1", "Brand 2"],
#     "selling_points": ["Key benefit 1", "Key benefit 2"],
#     "content_creative_ideas": "Description of innovative presentation approaches",
#     "emotional_value": "Description of emotional resonance created",
#   },
#
#   "user_analysis": {
#     "user_demographics": "Target user group description",
#     "user_preferences": "Typical preferences of target audience",
#     "user_pain_points": "Key frustrations addressed",
#     "user_goals": "Aspirations and objectives of users"
#   },
#
#   "performance_analysis": {
#     "content_style": "Description of stylistic approach",
#     "engagement_potential": "high|medium|low|very-high|unknown",
#     "trend_alignment": ["Current trend 1", "Current trend 2"],
#     "compliance_issues": ["auctions|exaggerated promises|false or misleading info|gambling & gamification|illegal or criminal activity|other"]
#   },
#
#   "optimization_suggestions": {
#     "content": ["Suggestion 1", "Suggestion 2"],
#     "product_placement": ["Suggestion 1", "Suggestion 2"],
#     "content_creative_ideas": ["Suggestion 1", "Suggestion 2"],
#     "emotional_value": ["Suggestion 1", "Suggestion 2"],
#     "compliance_issues": ["Suggestion 1", "Suggestion 2"]
#   }
# }
#
# IMPORTANT: Return ONLY the JSON object, no additional text or explanations. Use the exact field names and structure provided above. Choose values ONLY from the enumerated options provided for each field.
#
# API METADATA (from TikTok API):
# - Creator: alexandrasfinds1
# - Video ID: 7540866098422353166
# - Description: holy grail gives my lashes length AND volume #mascararoutine #lashroutine #maybellinemascara #mascara #mascarareview #viralproducts #viralmakeup #drugstoremakeup #tiktokshopcreatorpicks #volumelash
# - Hashtags: mascararoutine, lashroutine, maybellinemascara, mascara, mascarareview, viralproducts, viralmakeup, drugstoremakeup, tiktokshopcreatorpicks, volumelash
# - Is Ad: False, Is Commerce: False, Ad Authorization: False
# - Stats: likes=0, comments=0, shares=0, views=43
# - Duration: 36s, Created: 2025-08-21T02:52:17
#
#
# Audio transcription content: Just look at that length and volume it gave my lashes and something crazy for a reason if you guys wanted to get you're Hands on it. I'll link in this video for you.
#
# Frame 1 (representative_alexandrasfinds1_7540866098422353166_frame_0000.jpg):
# - BLIP description: a woman holding a yellow pencil in her mouth
# - Detected objects: person, toothbrush
#
# Frame 2 (representative_alexandrasfinds1_7540866098422353166_frame_0001.jpg):
# - BLIP description: a woman with long black hair and a white shirt is holding a brush
# - Detected objects: person
#
# Frame 3 (representative_alexandrasfinds1_7540866098422353166_frame_0002.jpg):
# - BLIP description: a woman with long black hair and a white shirt
# - Detected objects: person
# 2025-08-21 04:07:48,769 [INFO] MultimodalExtractor: ----------------------------------------
# 2025-08-21 04:07:50,214 [INFO] frame_analyzer: Selecting representative frames for video: boise_brooke_7540861540593880334
# 0: 640x384 1 person, 1 bowl, 1 orange, 1 couch, 1 bed, 17.2ms
# ...
# 2025-08-21 04:10:23,364 [INFO] MultimodalExtractor: Prompt content:
# 2025-08-21 04:10:23,365 [INFO] MultimodalExtractor: ----------------------------------------
# 2025-08-21 04:10:23,367 [INFO] MultimodalExtractor: You are a professional TikTok video content analysis expert with comprehensive knowledge of TikTok's content creator tag system.
# Analyze the provided video content (including frames, audio transcript, and metadata) and return ONLY a valid JSON response with the following unified structure:
#
# {
#   "video_description": "comprehensive description of the entire video content",
#   "primary_category": "beauty & personal care|fashion & accessories|home & lifestyle|sports & fitness|health & wellness|parenting & family|food & beverage|technology & gadgets|entertainment & gaming|travel & adventure|education & learning|pets & animals|automotive & transportation|business & finance|art & creativity|diy & crafts|comedy|dance|music|news & politics|science & nature|other",
#   "secondary_category": "skincare|makeup|haircare|fragrance|clothing|shoes|accessories|jewelry|home decor|kitchenware|gardening|fitness equipment|supplements|diet|mental health|recipes|restaurants|baking|adventure|hotels|budget travel|gadgets|apps|software|consoles|mobile games|team sports|yoga|running|early education|language learning|toddler care|teen issues|dog care|cat care|car reviews|motorcycles|investing|entrepreneurship|movies|tv shows|painting|knitting|woodworking|standup|skits|choreography|cover songs|current events|environment|other",
#   "tertiary_category": "specific product type or niche within secondary category",
#
#   "creator_analysis": {
#     "gender": "male|female|multiple-people|non-human|unknown",
#     "age": "child|teen|20s|30s|40s|50+|unknown",
#     "physical_appearance": "very appealing|appealing|average|distinctive|unknown",
#     "body_type": "slim|average|athletic|curvy|plus-size|unknown",
#     "hair_color": "black|brunette|blonde|red|mixed-colored|unknown|not-visible",
#     "hair_type": "straight|wavy|curly|coily|updo|tied|braids|unknown|not-visible",
#     "persona": ["fashionista|beauty guru|fitness enthusiast|foodie|traveler|tech geek|gamer|mommy blogger|pet lover|financial advisor|comedian|dancer|musician|educator|activist|artist|craftsman|lifestyle coach|health expert|reviewer|unboxer|vlogger|storyteller|influencer|model|expert"],
#     "charisma_authenticity": "enthusiastic & energetic|professional & authoritative|authentic & relatable|engaging & expressive|calm & soothing|unknown",
#     "economic_status": "luxury-focused|middle-class|budget-conscious|minimalist|unknown"
#   },
#
#   "content_analysis": {
#     "niche_specialty": ["skincare routines|makeup tutorials|hair styling|outfit ideas|home organization|workout plans|healthy recipes|travel hacks|tech reviews|gaming walkthroughs|parenting advice|pet training|car maintenance|investment tips|comedy skits|dance tutorials|song covers|educational content|art tutorials|diy projects|fashion hauls|beauty hauls|food reviews|budget travel tips|luxury unboxing|fitness challenges|mental health awareness|sustainable living"],
#     "content_format": ["tutorial|review|vlog|Q&A|challenge|prank|haul|day-in-the-life|how-to|tips & tricks|storytime|pov|comedy sketch|dance video|music video|educational|inspirational|motivational|interview|behind-the-scenes|unboxing|comparison|transformation|live stream"],
#     "overall_tone": ["informative|humorous|inspirational|relaxing|dramatic|romantic|sarcastic|upbeat|serious|mysterious|suspenseful|heartwarming|emotional|empowering|casual|formal"],
#     "energy_levels": "vibrant & passionate|composed & professional|calm & soothing|energetic & dynamic|relaxed & peaceful|unknown",
#     "visual_presentation": ["minimalist|bright & colorful|dark & moody|warm & cozy|professional lighting|natural lighting|dynamic editing|cinematic|aesthetic|raw & unfiltered|retro|futuristic|vintage"],
#     "product_presentation": ["product showcase|unboxing & reviews|voiceover content|live demonstrations|before & after comparisons|product comparisons|tutorial|haul|gift guide|collection|restock|routine|get ready with me|what's in my bag|try on haul"],
#     "video_quality": "very-high|high|moderate|low|unknown",
#     "video_scene": "daily life|family life|at work|professional settings|outdoor activities|social activities|travel scenes|special occasions|studio|bedroom|bathroom|kitchen|living room|garden|gym|cafe|restaurant|store|beach|mountains|city|countryside|other",
#     "video_background": "indoor|outdoor|kitchen|bedroom|living room|bathroom|office|studio|gym|cafe|restaurant|store|beach|mountains|city street|park|other",
#     "pacing": "very-fast|fast|moderate|slow|very-slow|unknown",
#     "speech_rate": "very-fast|fast|moderate|slow|very-slow|no-speech|unknown",
#     "face_visibility": "always-visible|frequently-visible|occasionally-visible|rarely-visible|never-visible|unknown",
#     "tiktok_effects": ["filters|ar-effects|text-overlay|green-screen|split-screens|stitches|duets|slow-motion|time-lapse|zoom-effects|transition-effects|voice-effects|stickers|emoji|none"]
#   },
#
#   "business_analysis": {
#     "commercial_intent": "commercial|non-commercial|educational|promotional|informational|entertainment|mixed",
#     "product_placement": "explicit|subtle|none|prominent|background|integrated",
#     "target_audience": "Detailed description of intended viewer demographics and interests",
#     "target_audience_fit": "low|moderate|high|very-high|unknown",
#     "engagement_drivers": ["promotional-sales|controversial-topics|clickbait|exaggerated-expression|relatable-struggle|satisfying-process|motivational-message|humor|emotional-story|shocking-facts|interactive-polls|user-participation|trending-music|celebration-events|exclusive-content"],
#     "trend_adoption": ["dance-challenges|audio-trends|meme-adaptations|pov-storytelling|seasonal-themes|hashtag-challenges|transition-challenges|outfit-challenges|recipe-trends|fitness-challenges|beauty-trends|comedy-trends|duet-chains|stitch-reactions"],
#     "branding_integration": "subtle|moderate|overt|not-present|seamless|forced|other",
#     "call_to_actions": ["like|share|comment|follow|link-in-bio|swipe-up|buy-now|join-live-stream|save|tag-friends|visit-website|download-app|sign-up|enter-giveaway|use-code"],
#     "has_discount": true,
#     "has_limited_time_discount": true,
#     "has_exclusive_discount": true
#   },
#
#   "product_analysis": {
#     "key_products": ["Product Name 1", "Product Name 2"],
#     "brands_mentioned": ["Brand 1", "Brand 2"],
#     "selling_points": ["Key benefit 1", "Key benefit 2"],
#     "content_creative_ideas": "Description of innovative presentation approaches",
#     "emotional_value": "Description of emotional resonance created",
#   },
#
#   "user_analysis": {
#     "user_demographics": "Target user group description",
#     "user_preferences": "Typical preferences of target audience",
#     "user_pain_points": "Key frustrations addressed",
#     "user_goals": "Aspirations and objectives of users"
#   },
#
#   "performance_analysis": {
#     "content_style": "Description of stylistic approach",
#     "engagement_potential": "high|medium|low|very-high|unknown",
#     "trend_alignment": ["Current trend 1", "Current trend 2"],
#     "compliance_issues": ["auctions|exaggerated promises|false or misleading info|gambling & gamification|illegal or criminal activity|other"]
#   },
#
#   "optimization_suggestions": {
#     "content": ["Suggestion 1", "Suggestion 2"],
#     "product_placement": ["Suggestion 1", "Suggestion 2"],
#     "content_creative_ideas": ["Suggestion 1", "Suggestion 2"],
#     "emotional_value": ["Suggestion 1", "Suggestion 2"],
#     "compliance_issues": ["Suggestion 1", "Suggestion 2"]
#   }
# }
#
# IMPORTANT: Return ONLY the JSON object, no additional text or explanations. Use the exact field names and structure provided above. Choose values ONLY from the enumerated options provided for each field.
#
# API METADATA (from TikTok API):
# - Creator: boise_brooke
# - Video ID: 7540799670956690702
# - Description: Replying to @rondawishuponastar Thank you! ❤️ #tiktokshopcreatorpicks #matureskin #over50 #over40 #mature
# - Hashtags: tiktokshopcreatorpicks, matureskin, over50, over40, mature
# - Is Ad: False, Is Commerce: False, Ad Authorization: False
# - Stats: likes=151, comments=16, shares=3, views=2215
# - Duration: 252s, Created: 2025-08-20T22:34:43
#
#
# Audio transcription content: Welcome to Get This, Not That, where I share the popular products that I love and the ones that I don't. I've got three super greens drinks. This one I don't . I feel I can taste the artificial sweetener. it's really strong. This one has a very mellow flavor. It doesn't taste greens. it's not too sweet. it's kind of drinking a flavored tea. This one, that's good. I can taste the greens, but it's also sweet, but not too sweet. And I kind of being able to taste the greens in this. I feel I'm doing something healthy. And I don't greens. Based on taste alone, I'm going to say Get This, not that. This is a very nice liquid, multi-vitamin that supports hair health. I've taken it off and on over the years when I can afford it, but it's expensive. I don't do that anymore. I take pumpkin seed oil for my hair. Pumpkin seed oil has many benefits. It helps prevent the hair from shedding and promote hair health. it's good for you're heart. it's good for you're bladder and urinary systems. Prostate, if you have one. you're skin, you're eyes. And it's really inexpensive to take this. And of course, I take my vitamin D3 every day because the antioxidant keeps me . And it's also good for you're brain. it's good for you're mood. And fish oil, which is also great for you're heart, great for you're brain. I'm very specific about the supplements I take now. And also, they're much less expensive. Maybe Get This, not that. This lip stain, , the one that goes on purple. it's really hard to get it on precisely. And then you have to leave it on a long time. I put off the purple. And for me, the lip stain was not even. It didn't stay on all day at all. Maybe stayed on a couple hours. it's a pain in the butt. I don't this product. I recently discovered Kulfi lip oil stain. Love this product. It goes on with a glossy oil kind of finish. And when the gloss wears off, it leaves the stain behind. The shiny look is gorgeous. The stain look is gorgeous. And the stain lasts for hours. Can you wipe it off? I have these two colors layered now. This is black cherry and this is rose. These are sleep gummies. And they're made of melatonin. It doesn't work for me. I don't it. It gives me a horrible hangover. These are Lullabytes sleep gummies. They don't have any melatonin. They have a special blend of five ingredients that are all natural. Not habit forming. I fall asleep fast. I stay asleep and I don't have a hangover. I've been taking these for 10 months and I'm a whole new person. Malax and Peel Shot. We got the white rice and the black rice. This one's supposedly stronger than this one. it's going to depend on you're skincare needs and goals. This is a very mild exfoliant compared to what I'm used to. To me, this is very surface level. If you have dead skin, it's probably going to exfoliate you're top layer of dead skin. If you have blackheads, this is great for blackheads. Maybe acne prone skin. I don't know. I think maybe it's targeted to a younger generation because it doesn't have a lot of amino acids or other chemical exfoliants. This is the MetaCube Exosome Shot Treatment 7500 strength. I've been using this for several months and it has completely transformed my skin. Not just at the surface level. It has three amino acids which are powerful chemical exfoliators. It goes deep inside you're skin and exfoliates from within you don't have dead skin. I do not have any dead skin on this face. I use this once a week. Once a week. This has a lot of anti-aging properties and as an older woman, this is better for me with the anti-aging properties. It has helped reduce my dark spots and evened out my skin tone and even helped reduce the appearance of wrinkles and fine lines. It has smoothed out my skin. My skin glows. it's bright and it's because of this. I to pair it with the PDRN Collagen Capsule Cream. This duo here once a week at night can completely transform you're skin. I'm not saying this is bad. I'm saying it's not for me. If yo ...
#
# Frame 1 (representative_boise_brooke_7540799670956690702_frame_0000.jpg):
# - BLIP description: a woman holding up a bottle of alcohol
# - Detected objects: person, bottle, book
#
# Frame 2 (representative_boise_brooke_7540799670956690702_frame_0001.jpg):
# - BLIP description: two women holding up some products in their hands
# - Detected objects: person, bottle, book, couch
#
# Frame 3 (representative_boise_brooke_7540799670956690702_frame_0002.jpg):
# - BLIP description: a woman holding up a box of yos and yos
# - Detected objects: person, cup
# 2025-08-21 04:10:23,368 [INFO] MultimodalExtractor: ----------------------------------------
# 2025-08-21 04:10:35,260 [INFO] httpx: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-21 04:10:35,263 [INFO] MultimodalExtractor: GPT4O API call completed - input tokens: 28754, output tokens: 910, cost: $0.0194
# 2025-08-21 04:10:35,264 [INFO] MultimodalExtractor: Cleaned JSON string: {
#   "video_description": "In this video, the creator shares her honest reviews of various health and beauty products, comparing those she loves with those she doesn't. She discusses super greens drinks, a liquid multi-vitamin, pumpkin seed oil, vitamin D3, fish oil, lip stains, sleep gummies, and sk...
# 2025-08-21 04:10:35,269 [INFO] MultimodalExtractor: Batch GPT4O analysis results saved to: data/analysis/boise_brooke/7540799670956690702/boise_brooke_7540799670956690702_batch_gpt4o_analysis.json
# 2025-08-21 04:10:35,343 [INFO] TikTokFeatureExtractor: Final analysis saved: data/analysis/boise_brooke/7540799670956690702/final_analysis.json, data/analysis/boise_brooke/7540799670956690702/final_analysis.csv
# 2025-08-21 04:10:35,344 [INFO] tiktok: [extract_video_features] finished, elapsed: 85.50 seconds
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 16
#       5 import src.main_batch as main_batch
#       7 sys.argv = [
#       8     'main_batch',
#       9     '--csv', '/app/data/creators.csv',
#    (...)     13     '-v'
#      14 ]
# ---> 16 await main_batch.main()
#
# File /app/src/main_batch.py:130, in main()
#     127 # 执行批量处理
#     128 start_time = asyncio.get_event_loop().time()
# --> 130 batch_id = await batch_processor.process_creators_from_csv(
#     131     str(csv_path),
#     132     batch_id=args.batch_id
#     133 )
#     135 end_time = asyncio.get_event_loop().time()
#     136 total_time = end_time - start_time
#
# File /app/src/batch_processor.py:113, in BatchProcessor.process_creators_from_csv(self, csv_path, batch_id)
#     110     self.progress_manager.create_batch(batch_id, [task.username for task in creator_tasks])
#     112     # Process in batches
# --> 113     await self._process_creators_in_batches(creator_tasks, batch_id)
#     115     return batch_id
#     117 except Exception as e:
#
# File /app/src/batch_processor.py:159, in BatchProcessor._process_creators_in_batches(self, creator_tasks, batch_id)
#     156 logger.info(f"📦 Processing batch {batch_num}/{total_batches}: {len(batch_tasks)} creators")
#     158 # Process current batch
# --> 159 await self._process_single_batch(batch_tasks, batch_id, batch_num)
#     161 # Inter-batch delay
#     162 if i + self.batch_size < total_creators:
#
# File /app/src/batch_processor.py:188, in BatchProcessor._process_single_batch(self, batch_tasks, batch_id, batch_num)
#     185     tasks.append(task_wrapper)
#     187 # Wait for all creators in this batch
# --> 188 results = await asyncio.gather(*tasks, return_exceptions=True)
#     190 # Aggregate batch results
#     191 successful = sum(1 for r in results if not isinstance(r, Exception))
#
# CancelledError:

# %%
df = extractor.extract_features_from_single_video(
    video_path="data/tiktok_videos/yasmalas.mp4", 
    output_folder="data/tiktok_frames", 
    csv_output_path=csv_output
)

# %%
df = extractor.extract_features_from_folder(
    video_folder=video_folder,
    output_folder=output_folder,
    csv_output_path=csv_output
)

# %%
import json
import matplotlib.pyplot as plt
from glob import glob

RESULTS_ROOT = 'data/tiktok_frames/' 

result_files = glob(os.path.join(RESULTS_ROOT, '**', 'audio_analysis_results.json'), recursive=True)

step_timings_list = []
video_names = []

for file in result_files:
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
        meta = data.get('metadata', {})
        timings = meta.get('step_timings', {})
        if timings:
            step_timings_list.append(timings)
            video_names.append(os.path.basename(os.path.dirname(file)))

if not step_timings_list:
    print('No step_timings found in results.')
else:
    df = pd.DataFrame(step_timings_list, index=video_names)
    print('Per-video step timings:')
    print(df)
    print('\nAverage step timings:')
    print(df.mean().sort_values(ascending=False))

    # Plot
    plt.figure(figsize=(10, 5))
    df.mean().sort_values(ascending=False).plot(kind='bar')
    plt.ylabel('Average Time (s)')
    plt.title('Average Step Timings Across Videos')
    plt.tight_layout()
    plt.show()
